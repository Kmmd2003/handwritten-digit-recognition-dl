# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
mnist = keras.datasets.mnist

# %%
(train_features, train_labels), (test_features, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
train_features.shape
# Out:
# (60000, 28, 28)

# %%
test_features.shape
# Out:
# (10000, 28, 28)

# %%
idx = 546
img = train_features[idx]
print(train_labels[idx])
plt.gray()
plt.imshow(img)
# Out:
# 3

# %% [markdown]
# # Preprocessing

# %%
np.min(img), np.max(img)
# Out:
# (np.uint8(0), np.uint8(255))

# %%
train_features = train_features / 255.0
test_features = test_features / 255.0

# %% [markdown]
# # Model definition

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=128, activation='relu'))
model.add(keras.layers.Dense(units=128, activation='relu'))
model.add(keras.layers.Dense(units=10, activation='softmax'))

# %%
model.compile(optimizer=tf.optimizers.Adam(), loss = tf.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
model.build(input_shape=(None, 28, 28))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
# ...

# %%
hist = model.fit(train_features, train_labels, epochs=1000, batch_size=256, validation_data=(test_features, test_labels))
# Out:
# Epoch 1/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8116 - loss: 0.7177 - val_accuracy: 0.9454 - val_loss: 0.1869
# Epoch 2/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9516 - loss: 0.1692 - val_accuracy: 0.9611 - val_loss: 0.1270
# Epoch 3/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1117 - val_accuracy: 0.9676 - val_loss: 0.1054
# Epoch 4/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9750 - loss: 0.0846 - val_accuracy: 0.9729 - val_loss: 0.0881
# Epoch 5/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9809 - loss: 0.0637 - val_accuracy: 0.9725 - val_loss: 0.0888
# Epoch 6/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0546 - val_accuracy: 0.9751 - val_loss: 0.0816
# Epoch 7/1000
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9880 - loss: 0.0409 - val_accuracy: 0.9743 - val_loss: 0.0803
# Epoch 8/1000
# ...

# %%
model.evaluate(test_features, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9747 - loss: 0.3800
# [0.3036043345928192, 0.9793999791145325]

# %%
idx = 139
img = test_features[idx]
print(test_labels[idx])
# Out:
# 4

# %%
plt.gray()
plt.imshow(img)

# %%
test_data = img.reshape(1, 28, 28)
test_data.shape
# Out:
# (1, 28, 28)

# %%
model.predict(test_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# array([[0.00000000e+00, 1.55818784e-40, 7.09057023e-42, 1.00407425e-16,
#         1.00000000e+00, 1.57968376e-40, 0.00000000e+00, 7.29998550e-24,
#         2.51066198e-32, 9.94486742e-18]], dtype=float32)

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

plt.plot(acc, color='blue')
plt.plot(val_acc, color='red')

# %%
# !git clone -b main https://github.com/Kmmd2003/handwritten-digit-recognition-dl.git
# Out:
# fatal: destination path 'handwritten-digit-recognition-dl' already exists and is not an empty directory.

# %%
# %cd YourRepo

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/digi-recognition-deep-learning.ipynb" .

# %%
! git add digi-recognition-deep-learning.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git
